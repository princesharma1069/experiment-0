# %% [markdown]
# exp 0 :
# Introduction to python

# %%
#Prince Kumar Sharma,PRN:25070123086
print("Prince Kumar Sharma")
# Out:
# Prince Kumar Sharma

# %%
print(2)
# Out:
# 2

# %%
print([1,2,5])
# Out:
# [1, 2, 5]

# %%
print("Prince Kumar Sharma")
print(2)
print([1,2,5])
# Out:
# Prince Kumar Sharma
# 2
# [1, 2, 5]

# %%
name = "prince kumar sharma"
number =2
matrix = [1,2,5]
print(name)
print(number)
print(matrix)
# Out:
# prince kumar sharma
# 2
# [1, 2, 5]

# %%
name = "prince kumar sharma"
number =2
matrix = [1,2,5]
print(name,number,matrix)
# Out:
# prince kumar sharma 2 [1, 2, 5]

# %%
name = "prince kumar sharma"
number =2
matrix = [1,2,5]
print(name,number,matrix,sep="\n")
# Out:
# prince kumar sharma
# 2
# [1, 2, 5]
